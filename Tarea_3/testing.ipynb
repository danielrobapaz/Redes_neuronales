# %%
import pandas as pd
from Neural_Network import Neural_Network
from Boosting import Boosting

# %%
lego = pd.read_csv('datasets/lego.csv')

# %%
lego['y'].value_counts(normalize=True)
# Out:
# 0    0.7002
# 1    0.2998
# Name: y, dtype: float64

# %% [markdown]
# ## Con momentum

# %%
Neural_Network(data=lego.copy(),
               number_of_neurons_hidden_layers=4,
               learning_rate=0.01,
               momentum=0.5,
               max_epoch=300)
# Out:
# Epoch 0 - MSE 0.26390754341257916
# Epoch 50 - MSE 0.07349020466595704
# Epoch 100 - MSE 0.06457642448763135
# Epoch 150 - MSE 0.0560785001546397
# Epoch 200 - MSE 0.04861045526524741
# Epoch 250 - MSE 0.04984157659604876
# accuracy - 0.938
# precision - 0.867
# sensivity - 0.949
# especificity - 0.933
# negative_predictive_value - 0.976

# %%
Boosting(data=lego,
         number_of_neurons_hidden_layers=10,
         learning_rate=0.01,
         momentum=0.23,
         max_epoch=300)
# Out:
# ::Expert 1
# Epoch 0 - MSE 0.23735347460597828
# Epoch 50 - MSE 0.172118976481382
# Epoch 100 - MSE 0.14820557635641735
# Epoch 150 - MSE 0.12662667234077837
# Epoch 200 - MSE 0.10846500853601763
# Epoch 250 - MSE 0.08735897001858797
# accuracy - 0.936
# precision - 0.892
# sensivity - 0.914
# especificity - 0.947
# negative_predictive_value - 0.958
# ::Expert 2
# Epoch 0 - MSE 0.2609758837074658
# Epoch 50 - MSE 0.2242143209664734
# Epoch 100 - MSE 0.19935452157616587
# Epoch 150 - MSE 0.19125258902420145
# Epoch 200 - MSE 0.1629428050691323
# Epoch 250 - MSE 0.14568691056040595
# /home/daniel/Documents/Trimestre/Introduccion_a_las_redes_neuronales/Redes_neuronales/Tarea_3/Neural_Network_2.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['network_y'] = network_y
# accuracy - 0.617
# precision - 0.427
# sensivity - 0.928
# especificity - 0.489
# negative_predictive_value - 0.943
# ::Expert 3
# Epoch 0 - MSE 0.523541005868112
# Epoch 50 - MSE 0.1273845816272721
# Epoch 100 - MSE 0.11559563011534257
# Epoch 150 - MSE 0.10389043633048768
# Epoch 200 - MSE 0.09657841055750356
# Epoch 250 - MSE 0.09315971281196377
# /home/daniel/Documents/Trimestre/Introduccion_a_las_redes_neuronales/Redes_neuronales/Tarea_3/Neural_Network_2.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['network_y'] = network_y
# accuracy - 0.835
# precision - 0.5
# sensivity - 0.655
# especificity - 0.871
# negative_predictive_value - 0.927
