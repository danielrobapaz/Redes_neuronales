# %%
import pandas as pd
from Neural_Network import Neural_Network

# %%
lego = pd.read_csv('datasets/lego.csv')

# %%
lego['y'].value_counts(normalize=True)
# Out:
# 0    0.7002
# 1    0.2998
# Name: y, dtype: float64

# %% [markdown]
# ## Con momentum

# %%
Neural_Network(data=lego,
               number_of_neurons_hidden_layers=15,
               learning_rate=0.01,
               momentum=0.3,
               max_epoch=150)
# Out:
# Epoch 20 - Error 38.15 %
# Epoch 40 - Error 39.375 %
# Epoch 60 - Error 40.375 %
# Epoch 80 - Error 41.45 %
# Epoch 100 - Error 41.35 %
# Epoch 120 - Error 39.4 %
# Epoch 140 - Error 41.45 %
# ::Training::
# Examples distribution in training
#  0    2814
# 1    1186
# Name: y, dtype: int64
# Convergence reached in 150 epochs
# with 40% of error
# ::Testing::
# Examples distribution in training
#  0    687
# 1    313
# Name: y, dtype: int64
# Number of bad clasified examples: 451 (45.1 %)
