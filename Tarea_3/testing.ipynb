# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from Neural_Network import Neural_Network

# %%
lego = pd.read_csv('datasets/lego.csv')
lego.head()
# Out:
#         x1       x2  y
# 0  0.58704  0.20774  0
# 1  0.30125  0.47092  1
# 2  0.23049  0.84431  0
# 3  0.19476  0.22592  0
# 4  0.17071  0.22766  0

# %%
fig, ax = plt.subplots()
sns.scatterplot(data=lego, 
                x='x1',
                y='x2',
                hue='y',
                ax=ax)

ax.set_title("Grafico de dispersion de los puntos en lego.csv")
ax.legend()
plt.show()

# %%
ej = pd.DataFrame({'x1': [0.5, 0.9],
                   'x2': [0.1, 0.7],
                   'y': [0, 1]})
ej
# Out:
#     x1   x2  y
# 0  0.5  0.1  0
# 1  0.9  0.7  1

# %%
Neural_Network(data = ej, 
               layers=[3, 10, 2, 2])
# Out:
# [-7.84146008e-05 -1.18911730e-04 -6.63365515e-05]
# [-3.73570253e-05 -1.26362123e-05 -8.76041258e-05 -7.72415361e-06
#  -1.25962903e-04 -9.56587101e-05 -5.30721022e-05 -5.04720422e-05
#  -3.32587461e-04 -1.22382596e-04]
# [-1.73145836e-03 -9.94137357e-05]
# [ 0.00636761 -0.10535602]
